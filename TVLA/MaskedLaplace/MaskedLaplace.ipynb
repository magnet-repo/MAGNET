# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# /home/mert/chipwhisperer/software/chipwhisperer/capture/trace/TraceWhisperer.py:31: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources # type: ignore
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 7733152                   to 18280440
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen

# %%
samples = 7700
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- MaskedLaplace-CW308_CC2538.hex MaskedLaplace-CW301_AVR.hex MaskedLaplace-CW303.hex MaskedLaplace-CW304.hex MaskedLaplace-CW308_MEGARF.hex MaskedLaplace-CW308_SAM4L.hex MaskedLaplace-CW308_STM32F0.hex MaskedLaplace-CW308_STM32F1.hex MaskedLaplace-CW308_STM32F2.hex MaskedLaplace-CW308_STM32F3.hex MaskedLaplace-CW308_STM32F4.hex MaskedLaplace-CW308_K24F.hex MaskedLaplace-CW308_NRF52.hex MaskedLaplace-CW308_AURIX.hex MaskedLaplace-CW308_SAML11.hex MaskedLaplace-CW308_EFM32TG11B.hex MaskedLaplace-CWLITEARM.hex MaskedLaplace-CWLITEXMEGA.hex MaskedLaplace-CWNANO.hex MaskedLaplace-CWHUSKY.hex MaskedLaplace-CW308_K82F.hex MaskedLaplace-CW308_PSOC62.hex MaskedLaplace-CW308_IMXRT1062.hex MaskedLaplace-CW308_FE310.hex MaskedLaplace-CW308_EFR32MG21A.hex MaskedLaplace-CW308_EFM32GG11.hex MaskedLaplace-CW308_STM32L5.hex MaskedLaplace-CW308_NEORV32.hex MaskedLaplace-CW312_SAM4S.hex MaskedLaplace-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# Compiling:
# .
# Compiling:
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# .
# .
# Compiling:
# .
# .
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# Assembling: Refresh_m4.S
# Assembling: SecNEG_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/Refresh_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ Refresh_m4.S -o objdir-CWLITEARM/Refresh_m4.o
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecNEG_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecNEG_m4.S -o objdir-CWLITEARM/SecNEG_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# .
# .
# .
# Assembling: SecAB_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAB_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAB_m4.S -o objdir-CWLITEARM/SecAB_m4.o
# .
# Assembling: SecBA_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecBA_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecBA_m4.S -o objdir-CWLITEARM/SecBA_m4.o
# Assembling: SecAND_m4.S
# Assembling: SecOR_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAND_m4.S -o objdir-CWLITEARM/SecAND_m4.o
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecOR_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecOR_m4.S -o objdir-CWLITEARM/SecOR_m4.o
# .
# .
# Assembling: SecINC_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecINC_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecINC_m4.S -o objdir-CWLITEARM/SecINC_m4.o
# .
# Assembling: MaskedBernoulli_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedBernoulli_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedBernoulli_m4.S -o objdir-CWLITEARM/MaskedBernoulli_m4.o
# Assembling: MaskedGeometric_m4.S
# .
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedGeometric_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedGeometric_m4.S -o objdir-CWLITEARM/MaskedGeometric_m4.o
# .
# Assembling: MaskedLaplace_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedLaplace_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedLaplace_m4.S -o objdir-CWLITEARM/MaskedLaplace_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     MaskedLaplace-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        2200 B        40 KB      5.37%
#              ROM:       23040 B       256 KB      8.79%
# -e Done!
# .
# .
# Creating load file for Flash: MaskedLaplace-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature MaskedLaplace-CWLITEARM.elf MaskedLaplace-CWLITEARM.hex
# Creating load file for Flash: MaskedLaplace-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature MaskedLaplace-CWLITEARM.elf MaskedLaplace-CWLITEARM.bin
# .
# Creating load file for EEPROM: MaskedLaplace-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex MaskedLaplace-CWLITEARM.elf MaskedLaplace-CWLITEARM.eep || exit 0
# .
# .
# Creating Extended Listing: MaskedLaplace-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z MaskedLaplace-CWLITEARM.elf > MaskedLaplace-CWLITEARM.lss
# Creating Symbol Table: MaskedLaplace-CWLITEARM.sym
# arm-none-eabi-nm -n MaskedLaplace-CWLITEARM.elf > MaskedLaplace-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   22932	    104	   2104	  25140	   6234	MaskedLaplace-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/MaskedLaplace-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 23039 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 23039 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        random_seed = bytearray([randbits(8) for _ in range(16)])
        
        target.simpleserial_write('p', random_seed)
         
        ret = scope.capture()
        t = scope.adc.trig_count
        if ret:
            print("Target timed out!")
        response = target.simpleserial_read('r', 1)
        res = int(response[0])
        if VERBOSE == True:
            print(res)
        if res == 0:
            traces_1.append(scope.get_last_trace())
        else:
            traces_2.append(scope.get_last_trace())

    print("#0s: ", len(traces_1))
    print("#Rnds: ", len(traces_2))
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
    #traces_1_arr = np.array(traces_1)
    #traces_2_arr = np.array(traces_2)
    #np.save('traces_1.npy', traces_1_arr)
    #np.save('traces_2.npy', traces_2_arr)
elif ch == 1:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
else:    
    traces_1 = np.load('traces_1.npy')
    traces_2 = np.load('traces_2.npy')
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3     VERBOSE = False
#       4     nb_traces = 200000
# ----> 5     traces_1, traces_2, x = get_traces(nb_traces)
#       6     #traces_1_arr = np.array(traces_1)
#       7     #traces_2_arr = np.array(traces_2)
#       8     #np.save('traces_1.npy', traces_1_arr)
#       9     #np.save('traces_2.npy', traces_2_arr)
#      10 elif ch == 1:
#
# Cell In[6], line 18, in get_traces(N)
#      14 random_seed = bytearray([randbits(8) for _ in range(16)])
#      16 target.simpleserial_write('p', random_seed)
# ---> 18 ret = scope.capture()
#      19 t = scope.adc.trig_count
#      20 if ret:
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:868, in OpenADC.capture(self, poll_done)
#     866     a = self.sc.capture(None)
#     867 else:
# --> 868     a = self.sc.capture(self.adc.offset, self.clock.adc_freq, self.adc.samples, self.adc.segments, self.adc.segment_cycles, poll_done)
#     870 # _capture_read() must be given the total number of samples to read; in the case of Husky, self.adc.samples
#     871 # is the number of samples *per segment*, so adjust accordingly:
#     872 if self._is_husky:
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:726, in OpenADCInterface.capture(self, offset, adc_freq, samples, segments, segment_cycles, poll_done)
#     724 # Wait for a trigger
#     725 while ((status & STATUS_ARM_MASK) == STATUS_ARM_MASK) | ((status & STATUS_FIFO_MASK) == 0):
# --> 726     status = self.getStatus()
#     728     diff = datetime.datetime.now() - starttime
#     730     # If we've timed out, don't wait any longer for a trigger
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:467, in OpenADCInterface.getStatus(self)
#     466 def getStatus(self):
# --> 467     result = self.sendMessage(CODE_READ, "STATUS_ADDR")
#     469     if len(result) == 1:
#     470         return result[0]
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:290, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     288 address = self._address_str2int(address)
#     289 if mode != CODE_WRITE:
# --> 290     return self.msg_read(address, maxResp)
#     291 self.msg_write(address, payload)
#     292 if Validate:
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:214, in OpenADCInterface.msg_read(self, address, max_resp)
#     211         scope_logger.warning("The error trace below will show you what led to this:")
#     212         raise ValueError
# --> 214     data = self.serial.cmdReadMem(address, max_resp)
#     215 else:
#     216     self._send_msg_hdr(CODE_READ, address, 0)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:889, in NAEUSB.cmdReadMem(self, addr, dlen)
#     883 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     884     """
#     885     Send command to read over external memory interface from FPGA. Automatically
#     886     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     887     """
# --> 889     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:635, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     633 dlen = int(dlen)
#     634 if dlen < NAEUSB_CTRL_IO_THRESHOLD:
# --> 635     data = self._cmd_readmem_ctrl(addr, dlen)
#     636 else:
#     637     data = self._cmd_readmem_bulk(addr, dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:616, in NAEUSB_Backend._cmd_readmem_ctrl(self, addr, dlen)
#     610 def _cmd_readmem_ctrl(self, addr : int, dlen : int):
#     611     """Reads data from the external memory interface over the control-transfer endpoint.
#     612
#     613     Returns:
#     614         The received data.
#     615     """
# --> 616     self._cmd_ctrl_send_header(addr, dlen, self.CMD_READMEM_CTRL);
#     617     return self.readCtrl(self.CMD_READMEM_CTRL, dlen=dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:608, in NAEUSB_Backend._cmd_ctrl_send_header(self, addr, dlen, cmd)
#     606 # TODO: Alloc header class member? Won't hafta alloc mem every read and writectrl call...
#     607 pload = make_len_addr(dlen, addr)
# --> 608 self._cmd_ctrl_send_data(pload, cmd)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:597, in NAEUSB_Backend._cmd_ctrl_send_data(self, pload, cmd)
#     593 """Sends data over the control-transfer channel and attempts a pipe error fix if an initial
#     594 error occured.
#     595 """
#     596 try:
# --> 597     self.sendCtrl(cmd, data=pload)
#     598 except usb1.USBErrorPipe:
#     599     naeusb_logger.info("Attempting pipe error fix - typically safe to ignore")
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:551, in NAEUSB_Backend.sendCtrl(self, cmd, value, data)
#     549 if len(data) > NAEUSB_CTRL_IO_MAX:
#     550     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 551 self.handle.controlWrite(0x41, cmd, value, 0, data, timeout=self._timeout)
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1406, in USBDeviceHandle.controlWrite(self, request_type, request, value, index, data, timeout)
#    1404 # pylint: enable=undefined-variable
#    1405 data, _ = create_initialised_buffer(data)
# -> 1406 return self._controlTransfer(request_type, request, value, index, data,
#    1407                              sizeof(data), timeout)
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1379, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
# -> 1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
#    1383     mayRaiseUSBError(result)
#    1384     return result
#
# KeyboardInterrupt:

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
