# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 500                       to 5000

# %%
samples = 350
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- Refresh-CW308_CC2538.hex Refresh-CW301_AVR.hex Refresh-CW303.hex Refresh-CW304.hex Refresh-CW308_MEGARF.hex Refresh-CW308_SAM4L.hex Refresh-CW308_STM32F0.hex Refresh-CW308_STM32F1.hex Refresh-CW308_STM32F2.hex Refresh-CW308_STM32F3.hex Refresh-CW308_STM32F4.hex Refresh-CW308_K24F.hex Refresh-CW308_NRF52.hex Refresh-CW308_AURIX.hex Refresh-CW308_SAML11.hex Refresh-CW308_EFM32TG11B.hex Refresh-CWLITEARM.hex Refresh-CWLITEXMEGA.hex Refresh-CWNANO.hex Refresh-CWHUSKY.hex Refresh-CW308_K82F.hex Refresh-CW308_PSOC62.hex Refresh-CW308_IMXRT1062.hex Refresh-CW308_FE310.hex Refresh-CW308_EFR32MG21A.hex Refresh-CW308_EFM32GG11.hex Refresh-CW308_STM32L5.hex Refresh-CW308_NEORV32.hex Refresh-CW312_SAM4S.hex Refresh-CW305_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- Refresh-CW308_CC2538.eep Refresh-CW301_AVR.eep Refresh-CW303.eep Refresh-CW304.eep Refresh-CW308_MEGARF.eep Refresh-CW308_SAM4L.eep Refresh-CW308_STM32F0.eep Refresh-CW308_STM32F1.eep Refresh-CW308_STM32F2.eep Refresh-CW308_STM32F3.eep Refresh-CW308_STM32F4.eep Refresh-CW308_K24F.eep Refresh-CW308_NRF52.eep Refresh-CW308_AURIX.eep Refresh-CW308_SAML11.eep Refresh-CW308_EFM32TG11B.eep Refresh-CWLITEARM.eep Refresh-CWLITEXMEGA.eep Refresh-CWNANO.eep Refresh-CWHUSKY.eep Refresh-CW308_K82F.eep Refresh-CW308_PSOC62.eep Refresh-CW308_IMXRT1062.eep Refresh-CW308_FE310.eep Refresh-CW308_EFR32MG21A.eep Refresh-CW308_EFM32GG11.eep Refresh-CW308_STM32L5.eep Refresh-CW308_NEORV32.eep Refresh-CW312_SAM4S.eep Refresh-CW305_IBEX.eep
# rm -f -- Refresh-CW308_CC2538.bin Refresh-CW301_AVR.bin Refresh-CW303.bin Refresh-CW304.bin Refresh-CW308_MEGARF.bin Refresh-CW308_SAM4L.bin Refresh-CW308_STM32F0.bin Refresh-CW308_STM32F1.bin Refresh-CW308_STM32F2.bin Refresh-CW308_STM32F3.bin Refresh-CW308_STM32F4.bin Refresh-CW308_K24F.bin Refresh-CW308_NRF52.bin Refresh-CW308_AURIX.bin Refresh-CW308_SAML11.bin Refresh-CW308_EFM32TG11B.bin Refresh-CWLITEARM.bin Refresh-CWLITEXMEGA.bin Refresh-CWNANO.bin Refresh-CWHUSKY.bin Refresh-CW308_K82F.bin Refresh-CW308_PSOC62.bin Refresh-CW308_IMXRT1062.bin Refresh-CW308_FE310.bin Refresh-CW308_EFR32MG21A.bin Refresh-CW308_EFM32GG11.bin Refresh-CW308_STM32L5.bin Refresh-CW308_NEORV32.bin Refresh-CW312_SAM4S.bin Refresh-CW305_IBEX.bin
# rm -f -- Refresh-CW308_CC2538.cof Refresh-CW301_AVR.cof Refresh-CW303.cof Refresh-CW304.cof Refresh-CW308_MEGARF.cof Refresh-CW308_SAM4L.cof Refresh-CW308_STM32F0.cof Refresh-CW308_STM32F1.cof Refresh-CW308_STM32F2.cof Refresh-CW308_STM32F3.cof Refresh-CW308_STM32F4.cof Refresh-CW308_K24F.cof Refresh-CW308_NRF52.cof Refresh-CW308_AURIX.cof Refresh-CW308_SAML11.cof Refresh-CW308_EFM32TG11B.cof Refresh-CWLITEARM.cof Refresh-CWLITEXMEGA.cof Refresh-CWNANO.cof Refresh-CWHUSKY.cof Refresh-CW308_K82F.cof Refresh-CW308_PSOC62.cof Refresh-CW308_IMXRT1062.cof Refresh-CW308_FE310.cof Refresh-CW308_EFR32MG21A.cof Refresh-CW308_EFM32GG11.cof Refresh-CW308_STM32L5.cof Refresh-CW308_NEORV32.cof Refresh-CW312_SAM4S.cof Refresh-CW305_IBEX.cof
# rm -f -- Refresh-CW308_CC2538.elf Refresh-CW301_AVR.elf Refresh-CW303.elf Refresh-CW304.elf Refresh-CW308_MEGARF.elf Refresh-CW308_SAM4L.elf Refresh-CW308_STM32F0.elf Refresh-CW308_STM32F1.elf Refresh-CW308_STM32F2.elf Refresh-CW308_STM32F3.elf Refresh-CW308_STM32F4.elf Refresh-CW308_K24F.elf Refresh-CW308_NRF52.elf Refresh-CW308_AURIX.elf Refresh-CW308_SAML11.elf Refresh-CW308_EFM32TG11B.elf Refresh-CWLITEARM.elf Refresh-CWLITEXMEGA.elf Refresh-CWNANO.elf Refresh-CWHUSKY.elf Refresh-CW308_K82F.elf Refresh-CW308_PSOC62.elf Refresh-CW308_IMXRT1062.elf Refresh-CW308_FE310.elf Refresh-CW308_EFR32MG21A.elf Refresh-CW308_EFM32GG11.elf Refresh-CW308_STM32L5.elf Refresh-CW308_NEORV32.elf Refresh-CW312_SAM4S.elf Refresh-CW305_IBEX.elf
# rm -f -- Refresh-CW308_CC2538.map Refresh-CW301_AVR.map Refresh-CW303.map Refresh-CW304.map Refresh-CW308_MEGARF.map Refresh-CW308_SAM4L.map Refresh-CW308_STM32F0.map Refresh-CW308_STM32F1.map Refresh-CW308_STM32F2.map Refresh-CW308_STM32F3.map Refresh-CW308_STM32F4.map Refresh-CW308_K24F.map Refresh-CW308_NRF52.map Refresh-CW308_AURIX.map Refresh-CW308_SAML11.map Refresh-CW308_EFM32TG11B.map Refresh-CWLITEARM.map Refresh-CWLITEXMEGA.map Refresh-CWNANO.map Refresh-CWHUSKY.map Refresh-CW308_K82F.map Refresh-CW308_PSOC62.map Refresh-CW308_IMXRT1062.map Refresh-CW308_FE310.map Refresh-CW308_EFR32MG21A.map Refresh-CW308_EFM32GG11.map Refresh-CW308_STM32L5.map Refresh-CW308_NEORV32.map Refresh-CW312_SAM4S.map Refresh-CW305_IBEX.map
# rm -f -- Refresh-CW308_CC2538.sym Refresh-CW301_AVR.sym Refresh-CW303.sym Refresh-CW304.sym Refresh-CW308_MEGARF.sym Refresh-CW308_SAM4L.sym Refresh-CW308_STM32F0.sym Refresh-CW308_STM32F1.sym Refresh-CW308_STM32F2.sym Refresh-CW308_STM32F3.sym Refresh-CW308_STM32F4.sym Refresh-CW308_K24F.sym Refresh-CW308_NRF52.sym Refresh-CW308_AURIX.sym Refresh-CW308_SAML11.sym Refresh-CW308_EFM32TG11B.sym Refresh-CWLITEARM.sym Refresh-CWLITEXMEGA.sym Refresh-CWNANO.sym Refresh-CWHUSKY.sym Refresh-CW308_K82F.sym Refresh-CW308_PSOC62.sym Refresh-CW308_IMXRT1062.sym Refresh-CW308_FE310.sym Refresh-CW308_EFR32MG21A.sym Refresh-CW308_EFM32GG11.sym Refresh-CW308_STM32L5.sym Refresh-CW308_NEORV32.sym Refresh-CW312_SAM4S.sym Refresh-CW305_IBEX.sym
# rm -f -- Refresh-CW308_CC2538.lss Refresh-CW301_AVR.lss Refresh-CW303.lss Refresh-CW304.lss Refresh-CW308_MEGARF.lss Refresh-CW308_SAM4L.lss Refresh-CW308_STM32F0.lss Refresh-CW308_STM32F1.lss Refresh-CW308_STM32F2.lss Refresh-CW308_STM32F3.lss Refresh-CW308_STM32F4.lss Refresh-CW308_K24F.lss Refresh-CW308_NRF52.lss Refresh-CW308_AURIX.lss Refresh-CW308_SAML11.lss Refresh-CW308_EFM32TG11B.lss Refresh-CWLITEARM.lss Refresh-CWLITEXMEGA.lss Refresh-CWNANO.lss Refresh-CWHUSKY.lss Refresh-CW308_K82F.lss Refresh-CW308_PSOC62.lss Refresh-CW308_IMXRT1062.lss Refresh-CW308_FE310.lss Refresh-CW308_EFR32MG21A.lss Refresh-CW308_EFM32GG11.lss Refresh-CW308_STM32L5.lss Refresh-CW308_NEORV32.lss Refresh-CW312_SAM4S.lss Refresh-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# .
# Compiling:
# Compiling:
# -en     project.c ...
# Compiling:
# .
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# .
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# Compiling:
# .
# Assembling: Refresh_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/Refresh_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ Refresh_m4.S -o objdir-CWLITEARM/Refresh_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     Refresh-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       10724 B       256 KB      4.09%
# -e Done!
# .
# .
# .
# Creating load file for Flash: Refresh-CWLITEARM.hex
# .
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature Refresh-CWLITEARM.elf Refresh-CWLITEARM.hex
# Creating load file for Flash: Refresh-CWLITEARM.bin
# Creating load file for EEPROM: Refresh-CWLITEARM.eep
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature Refresh-CWLITEARM.elf Refresh-CWLITEARM.bin
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex Refresh-CWLITEARM.elf Refresh-CWLITEARM.eep || exit 0
# Creating Extended Listing: Refresh-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z Refresh-CWLITEARM.elf > Refresh-CWLITEARM.lss
# .
# Creating Symbol Table: Refresh-CWLITEARM.sym
# arm-none-eabi-nm -n Refresh-CWLITEARM.elf > Refresh-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   10700	     24	   1688	  12412	   307c	Refresh-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/Refresh-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 10723 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 10723 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 42
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = FIXED ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])

        randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = (x0 ^ x1)

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            
            val = (rnd_x0 ^ rnd_x1) 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())
 
        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 340 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
plt.close()
for t in traces_1[:1]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
