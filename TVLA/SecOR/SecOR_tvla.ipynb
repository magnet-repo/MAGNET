# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 1300                      to 5000

# %%
GADGET = "OR_"  # possible values are ["AB", "BA", "AND", "ADD", "ZERO"]
ARCH = 'asm' # possible values are ["c", "asm", "naive_asm"]

if ARCH == 'asm':
    samples = {"AB": 1600, "BA": 600, "AND": 900, "OR_": 1300, "ADD": 1100, "ZERO": 1200}
elif ARCH == 'naive_asm':
    samples = {"AB": 600, "BA": 300, "AND": 300, "ADD": 700, "ZERO": 600}
elif ARCH == 'c':
    samples = {"AB": 500, "BA": 200, "AND": 300, "ADD": 500, "ZERO": 500}

randomness = {"AB":2, "BA": 2, "AND": 2, "OR_": 2, "ADD": 6, "ZERO": 18}
RAND = randomness[GADGET]
scope.adc.samples = samples[GADGET]

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER" "$GADGET" "$ARCH" "$RAND"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 GADGET=$4 ARCH=$5 RAND=$6 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- secOR-CW308_CC2538.hex secOR-CW301_AVR.hex secOR-CW303.hex secOR-CW304.hex secOR-CW308_MEGARF.hex secOR-CW308_SAM4L.hex secOR-CW308_STM32F0.hex secOR-CW308_STM32F1.hex secOR-CW308_STM32F2.hex secOR-CW308_STM32F3.hex secOR-CW308_STM32F4.hex secOR-CW308_K24F.hex secOR-CW308_NRF52.hex secOR-CW308_AURIX.hex secOR-CW308_SAML11.hex secOR-CW308_EFM32TG11B.hex secOR-CWLITEARM.hex secOR-CWLITEXMEGA.hex secOR-CWNANO.hex secOR-CWHUSKY.hex secOR-CW308_K82F.hex secOR-CW308_PSOC62.hex secOR-CW308_IMXRT1062.hex secOR-CW308_FE310.hex secOR-CW308_EFR32MG21A.hex secOR-CW308_EFM32GG11.hex secOR-CW308_STM32L5.hex secOR-CW308_NEORV32.hex secOR-CW312_SAM4S.hex secOR-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# rm -f -- secOR-CW308_CC2538.eep secOR-CW301_AVR.eep secOR-CW303.eep secOR-CW304.eep secOR-CW308_MEGARF.eep secOR-CW308_SAM4L.eep secOR-CW308_STM32F0.eep secOR-CW308_STM32F1.eep secOR-CW308_STM32F2.eep secOR-CW308_STM32F3.eep secOR-CW308_STM32F4.eep secOR-CW308_K24F.eep secOR-CW308_NRF52.eep secOR-CW308_AURIX.eep secOR-CW308_SAML11.eep secOR-CW308_EFM32TG11B.eep secOR-CWLITEARM.eep secOR-CWLITEXMEGA.eep secOR-CWNANO.eep secOR-CWHUSKY.eep secOR-CW308_K82F.eep secOR-CW308_PSOC62.eep secOR-CW308_IMXRT1062.eep secOR-CW308_FE310.eep secOR-CW308_EFR32MG21A.eep secOR-CW308_EFM32GG11.eep secOR-CW308_STM32L5.eep secOR-CW308_NEORV32.eep secOR-CW312_SAM4S.eep secOR-CW305_IBEX.eep
# rm -f -- secOR-CW308_CC2538.bin secOR-CW301_AVR.bin secOR-CW303.bin secOR-CW304.bin secOR-CW308_MEGARF.bin secOR-CW308_SAM4L.bin secOR-CW308_STM32F0.bin secOR-CW308_STM32F1.bin secOR-CW308_STM32F2.bin secOR-CW308_STM32F3.bin secOR-CW308_STM32F4.bin secOR-CW308_K24F.bin secOR-CW308_NRF52.bin secOR-CW308_AURIX.bin secOR-CW308_SAML11.bin secOR-CW308_EFM32TG11B.bin secOR-CWLITEARM.bin secOR-CWLITEXMEGA.bin secOR-CWNANO.bin secOR-CWHUSKY.bin secOR-CW308_K82F.bin secOR-CW308_PSOC62.bin secOR-CW308_IMXRT1062.bin secOR-CW308_FE310.bin secOR-CW308_EFR32MG21A.bin secOR-CW308_EFM32GG11.bin secOR-CW308_STM32L5.bin secOR-CW308_NEORV32.bin secOR-CW312_SAM4S.bin secOR-CW305_IBEX.bin
# rm -f -- secOR-CW308_CC2538.cof secOR-CW301_AVR.cof secOR-CW303.cof secOR-CW304.cof secOR-CW308_MEGARF.cof secOR-CW308_SAM4L.cof secOR-CW308_STM32F0.cof secOR-CW308_STM32F1.cof secOR-CW308_STM32F2.cof secOR-CW308_STM32F3.cof secOR-CW308_STM32F4.cof secOR-CW308_K24F.cof secOR-CW308_NRF52.cof secOR-CW308_AURIX.cof secOR-CW308_SAML11.cof secOR-CW308_EFM32TG11B.cof secOR-CWLITEARM.cof secOR-CWLITEXMEGA.cof secOR-CWNANO.cof secOR-CWHUSKY.cof secOR-CW308_K82F.cof secOR-CW308_PSOC62.cof secOR-CW308_IMXRT1062.cof secOR-CW308_FE310.cof secOR-CW308_EFR32MG21A.cof secOR-CW308_EFM32GG11.cof secOR-CW308_STM32L5.cof secOR-CW308_NEORV32.cof secOR-CW312_SAM4S.cof secOR-CW305_IBEX.cof
# rm -f -- secOR-CW308_CC2538.elf secOR-CW301_AVR.elf secOR-CW303.elf secOR-CW304.elf secOR-CW308_MEGARF.elf secOR-CW308_SAM4L.elf secOR-CW308_STM32F0.elf secOR-CW308_STM32F1.elf secOR-CW308_STM32F2.elf secOR-CW308_STM32F3.elf secOR-CW308_STM32F4.elf secOR-CW308_K24F.elf secOR-CW308_NRF52.elf secOR-CW308_AURIX.elf secOR-CW308_SAML11.elf secOR-CW308_EFM32TG11B.elf secOR-CWLITEARM.elf secOR-CWLITEXMEGA.elf secOR-CWNANO.elf secOR-CWHUSKY.elf secOR-CW308_K82F.elf secOR-CW308_PSOC62.elf secOR-CW308_IMXRT1062.elf secOR-CW308_FE310.elf secOR-CW308_EFR32MG21A.elf secOR-CW308_EFM32GG11.elf secOR-CW308_STM32L5.elf secOR-CW308_NEORV32.elf secOR-CW312_SAM4S.elf secOR-CW305_IBEX.elf
# rm -f -- secOR-CW308_CC2538.map secOR-CW301_AVR.map secOR-CW303.map secOR-CW304.map secOR-CW308_MEGARF.map secOR-CW308_SAM4L.map secOR-CW308_STM32F0.map secOR-CW308_STM32F1.map secOR-CW308_STM32F2.map secOR-CW308_STM32F3.map secOR-CW308_STM32F4.map secOR-CW308_K24F.map secOR-CW308_NRF52.map secOR-CW308_AURIX.map secOR-CW308_SAML11.map secOR-CW308_EFM32TG11B.map secOR-CWLITEARM.map secOR-CWLITEXMEGA.map secOR-CWNANO.map secOR-CWHUSKY.map secOR-CW308_K82F.map secOR-CW308_PSOC62.map secOR-CW308_IMXRT1062.map secOR-CW308_FE310.map secOR-CW308_EFR32MG21A.map secOR-CW308_EFM32GG11.map secOR-CW308_STM32L5.map secOR-CW308_NEORV32.map secOR-CW312_SAM4S.map secOR-CW305_IBEX.map
# rm -f -- secOR-CW308_CC2538.sym secOR-CW301_AVR.sym secOR-CW303.sym secOR-CW304.sym secOR-CW308_MEGARF.sym secOR-CW308_SAM4L.sym secOR-CW308_STM32F0.sym secOR-CW308_STM32F1.sym secOR-CW308_STM32F2.sym secOR-CW308_STM32F3.sym secOR-CW308_STM32F4.sym secOR-CW308_K24F.sym secOR-CW308_NRF52.sym secOR-CW308_AURIX.sym secOR-CW308_SAML11.sym secOR-CW308_EFM32TG11B.sym secOR-CWLITEARM.sym secOR-CWLITEXMEGA.sym secOR-CWNANO.sym secOR-CWHUSKY.sym secOR-CW308_K82F.sym secOR-CW308_PSOC62.sym secOR-CW308_IMXRT1062.sym secOR-CW308_FE310.sym secOR-CW308_EFR32MG21A.sym secOR-CW308_EFM32GG11.sym secOR-CW308_STM32L5.sym secOR-CW308_NEORV32.sym secOR-CW312_SAM4S.sym secOR-CW305_IBEX.sym
# rm -f -- secOR-CW308_CC2538.lss secOR-CW301_AVR.lss secOR-CW303.lss secOR-CW304.lss secOR-CW308_MEGARF.lss secOR-CW308_SAM4L.lss secOR-CW308_STM32F0.lss secOR-CW308_STM32F1.lss secOR-CW308_STM32F2.lss secOR-CW308_STM32F3.lss secOR-CW308_STM32F4.lss secOR-CW308_K24F.lss secOR-CW308_NRF52.lss secOR-CW308_AURIX.lss secOR-CW308_SAML11.lss secOR-CW308_EFM32TG11B.lss secOR-CWLITEARM.lss secOR-CWLITEXMEGA.lss secOR-CWNANO.lss secOR-CWHUSKY.lss secOR-CW308_K82F.lss secOR-CW308_PSOC62.lss secOR-CW308_IMXRT1062.lss secOR-CW308_FE310.lss secOR-CW308_EFR32MG21A.lss secOR-CW308_EFM32GG11.lss secOR-CW308_STM32L5.lss secOR-CW308_NEORV32.lss secOR-CW312_SAM4S.lss secOR-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# Compiling:
# Compiling:
# .
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# Compiling:
# .
# -en     ../../../firmware/mcu/hal/hal.c ...
# .
# Compiling:
# .
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# .
# Assembling: secOR_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/secOR_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ secOR_m4.S -o objdir-CWLITEARM/secOR_m4.o
# .
# .
# Assembling: secAND_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/secAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ secAND_m4.S -o objdir-CWLITEARM/secAND_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# project.c: In function 'get_pt':
# project.c:41:5: warning: implicit declaration of function 'secOR_m4' [-Wimplicit-function-declaration]
#    41 |     secOR_m4(zp, xp, yp, up);
#       |     ^~~~~~~~
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     secOR-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       11096 B       256 KB      4.23%
# -e Done!
# .
# .
# .
# Creating load file for Flash: secOR-CWLITEARM.hex
# .
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature secOR-CWLITEARM.elf secOR-CWLITEARM.hex
# Creating load file for Flash: secOR-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature secOR-CWLITEARM.elf secOR-CWLITEARM.bin
# Creating load file for EEPROM: secOR-CWLITEARM.eep
# Creating Extended Listing: secOR-CWLITEARM.lss
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex secOR-CWLITEARM.elf secOR-CWLITEARM.eep || exit 0
# arm-none-eabi-objdump -h -S -z secOR-CWLITEARM.elf > secOR-CWLITEARM.lss
# .
# Creating Symbol Table: secOR-CWLITEARM.sym
# arm-none-eabi-nm -n secOR-CWLITEARM.elf > secOR-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   11072	     24	   1688	  12784	   31f0	secOR-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/secOR-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 11095 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 11095 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = FIXED ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])

        mask = randbits(32)
        y0 = FIXED ^ mask
        y1 = mask

        y0_0 = y0 % (2**8)
        y0_1 = (y0 % (2**16)) >> 8
        y0_2 = (y0 % (2**24)) >> 16
        y0_3 = y0 >> 24

        y1_0 = y1 % (2**8)
        y1_1 = (y1 % (2**16)) >> 8
        y1_2 = (y1 % (2**24)) >> 16
        y1_3 = y1 >> 24
        
        fixed_text.extend([y0_0, y0_1, y0_2, y0_3, y1_0, y1_1, y1_2, y1_3])

        randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = ((x0 ^ x1) | (y0 ^ y1)) % 2**32 

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            #print(t)
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            rnd_y0 = (text[11] << 24) |(text[10] << 16) | (text[9] << 8) | text[8]
            rnd_y1 = (text[15] << 24) |(text[14] << 16) | (text[13] << 8) | text[12]
            
            val = ((rnd_x0 ^ rnd_x1) | (rnd_y0 ^ rnd_y1)) % 2**32 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())
 
        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
load = 0
if load == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
    #traces_1_arr = np.array(traces_1)
    #traces_2_arr = np.array(traces_2)
    #np.save('traces_1.npy', traces_1_arr)
    #np.save('traces_2.npy', traces_2_arr)
else:
    traces_1 = np.load('traces_1.npy')
    traces_2 = np.load('traces_2.npy')
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 876 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples[GADGET])
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples

t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.5)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color = 'r')
plt.ylim(-25, 25)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
plt.close()
for t in traces_1[:1]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
np.save("t-test-{}-{}-{}.npy".format(str(nb_traces), GADGET, ARCH), t_val)

# %%
target.dis()
scope.dis()
# Out:
# True
