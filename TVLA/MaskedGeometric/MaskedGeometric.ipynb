# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 4000                      to 5000

# %%
samples = 3500
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- MaskedGeometric-CW308_CC2538.hex MaskedGeometric-CW301_AVR.hex MaskedGeometric-CW303.hex MaskedGeometric-CW304.hex MaskedGeometric-CW308_MEGARF.hex MaskedGeometric-CW308_SAM4L.hex MaskedGeometric-CW308_STM32F0.hex MaskedGeometric-CW308_STM32F1.hex MaskedGeometric-CW308_STM32F2.hex MaskedGeometric-CW308_STM32F3.hex MaskedGeometric-CW308_STM32F4.hex MaskedGeometric-CW308_K24F.hex MaskedGeometric-CW308_NRF52.hex MaskedGeometric-CW308_AURIX.hex MaskedGeometric-CW308_SAML11.hex MaskedGeometric-CW308_EFM32TG11B.hex MaskedGeometric-CWLITEARM.hex MaskedGeometric-CWLITEXMEGA.hex MaskedGeometric-CWNANO.hex MaskedGeometric-CWHUSKY.hex MaskedGeometric-CW308_K82F.hex MaskedGeometric-CW308_PSOC62.hex MaskedGeometric-CW308_IMXRT1062.hex MaskedGeometric-CW308_FE310.hex MaskedGeometric-CW308_EFR32MG21A.hex MaskedGeometric-CW308_EFM32GG11.hex MaskedGeometric-CW308_STM32L5.hex MaskedGeometric-CW308_NEORV32.hex MaskedGeometric-CW312_SAM4S.hex MaskedGeometric-CW305_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- MaskedGeometric-CW308_CC2538.eep MaskedGeometric-CW301_AVR.eep MaskedGeometric-CW303.eep MaskedGeometric-CW304.eep MaskedGeometric-CW308_MEGARF.eep MaskedGeometric-CW308_SAM4L.eep MaskedGeometric-CW308_STM32F0.eep MaskedGeometric-CW308_STM32F1.eep MaskedGeometric-CW308_STM32F2.eep MaskedGeometric-CW308_STM32F3.eep MaskedGeometric-CW308_STM32F4.eep MaskedGeometric-CW308_K24F.eep MaskedGeometric-CW308_NRF52.eep MaskedGeometric-CW308_AURIX.eep MaskedGeometric-CW308_SAML11.eep MaskedGeometric-CW308_EFM32TG11B.eep MaskedGeometric-CWLITEARM.eep MaskedGeometric-CWLITEXMEGA.eep MaskedGeometric-CWNANO.eep MaskedGeometric-CWHUSKY.eep MaskedGeometric-CW308_K82F.eep MaskedGeometric-CW308_PSOC62.eep MaskedGeometric-CW308_IMXRT1062.eep MaskedGeometric-CW308_FE310.eep MaskedGeometric-CW308_EFR32MG21A.eep MaskedGeometric-CW308_EFM32GG11.eep MaskedGeometric-CW308_STM32L5.eep MaskedGeometric-CW308_NEORV32.eep MaskedGeometric-CW312_SAM4S.eep MaskedGeometric-CW305_IBEX.eep
# rm -f -- MaskedGeometric-CW308_CC2538.lss MaskedGeometric-CW301_AVR.lss MaskedGeometric-CW303.lss MaskedGeometric-CW304.lss MaskedGeometric-CW308_MEGARF.lss MaskedGeometric-CW308_SAM4L.lss MaskedGeometric-CW308_STM32F0.lss MaskedGeometric-CW308_STM32F1.lss MaskedGeometric-CW308_STM32F2.lss MaskedGeometric-CW308_STM32F3.lss MaskedGeometric-CW308_STM32F4.lss MaskedGeometric-CW308_K24F.lss MaskedGeometric-CW308_NRF52.lss MaskedGeometric-CW308_AURIX.lss MaskedGeometric-CW308_SAML11.lss MaskedGeometric-CW308_EFM32TG11B.lss MaskedGeometric-CWLITEARM.lss MaskedGeometric-CWLITEXMEGA.lss MaskedGeometric-CWNANO.lss MaskedGeometric-CWHUSKY.lss MaskedGeometric-CW308_K82F.lss MaskedGeometric-CW308_PSOC62.lss MaskedGeometric-CW308_IMXRT1062.lss MaskedGeometric-CW308_FE310.lss MaskedGeometric-CW308_EFR32MG21A.lss MaskedGeometric-CW308_EFM32GG11.lss MaskedGeometric-CW308_STM32L5.lss MaskedGeometric-CW308_NEORV32.lss MaskedGeometric-CW312_SAM4S.lss MaskedGeometric-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# .
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# .
# Compiling:
# .
# Assembling: Refresh_m4.S
# .
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/Refresh_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ Refresh_m4.S -o objdir-CWLITEARM/Refresh_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: SecAND_m4.S
# .
# Assembling: SecOR_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAND_m4.S -o objdir-CWLITEARM/SecAND_m4.o
# .
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecOR_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecOR_m4.S -o objdir-CWLITEARM/SecOR_m4.o
# Assembling: MaskedBernoulli_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedBernoulli_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedBernoulli_m4.S -o objdir-CWLITEARM/MaskedBernoulli_m4.o
# Assembling: MaskedGeometric_m4.S
# .
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedGeometric_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedGeometric_m4.S -o objdir-CWLITEARM/MaskedGeometric_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     MaskedGeometric-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        2216 B        40 KB      5.41%
#              ROM:       21760 B       256 KB      8.30%
# -e Done!
# .
# .
# .
# Creating load file for Flash: MaskedGeometric-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature MaskedGeometric-CWLITEARM.elf MaskedGeometric-CWLITEARM.hex
# Creating load file for Flash: MaskedGeometric-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature MaskedGeometric-CWLITEARM.elf MaskedGeometric-CWLITEARM.bin
# Creating load file for EEPROM: MaskedGeometric-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex MaskedGeometric-CWLITEARM.elf MaskedGeometric-CWLITEARM.eep || exit 0
# .
# .
# Creating Extended Listing: MaskedGeometric-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z MaskedGeometric-CWLITEARM.elf > MaskedGeometric-CWLITEARM.lss
# Creating Symbol Table: MaskedGeometric-CWLITEARM.sym
# arm-none-eabi-nm -n MaskedGeometric-CWLITEARM.elf > MaskedGeometric-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   21652	    104	   2120	  23876	   5d44	MaskedGeometric-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/MaskedGeometric-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 21759 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 21759 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        random_seed = bytearray([randbits(8) for _ in range(16)])
        
        target.simpleserial_write('p', random_seed)
         
        ret = scope.capture()
        t = scope.adc.trig_count
        if ret:
            print("Target timed out!")
        response = target.simpleserial_read('r', 1)
        res = int(response[0])
        if VERBOSE == True:
            print(res)
        if res == 2:
            traces_1.append(scope.get_last_trace())
        else:
            traces_2.append(scope.get_last_trace())

    print("#2s: ", len(traces_1))
    print("#Rnds: ", len(traces_2))
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# #2s:  100039
# #Rnds:  99961
# Trigger up for 3492 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
