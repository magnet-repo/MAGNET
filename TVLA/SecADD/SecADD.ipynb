# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 9424277                   to 36812624
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 0                         to 25176246
# scope.clock.adc_rate                     changed from 0.0                       to 25176246.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.cdc_settings                    changed from [1, 0, 0, 0]              to [0, 0, 0, 0]

# %%
samples = 2500
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecADD-CW308_CC2538.hex SecADD-CW301_AVR.hex SecADD-CW303.hex SecADD-CW304.hex SecADD-CW308_MEGARF.hex SecADD-CW308_SAM4L.hex SecADD-CW308_STM32F0.hex SecADD-CW308_STM32F1.hex SecADD-CW308_STM32F2.hex SecADD-CW308_STM32F3.hex SecADD-CW308_STM32F4.hex SecADD-CW308_K24F.hex SecADD-CW308_NRF52.hex SecADD-CW308_AURIX.hex SecADD-CW308_SAML11.hex SecADD-CW308_EFM32TG11B.hex SecADD-CWLITEARM.hex SecADD-CWLITEXMEGA.hex SecADD-CWNANO.hex SecADD-CWHUSKY.hex SecADD-CW308_K82F.hex SecADD-CW308_PSOC62.hex SecADD-CW308_IMXRT1062.hex SecADD-CW308_FE310.hex SecADD-CW308_EFR32MG21A.hex SecADD-CW308_EFM32GG11.hex SecADD-CW308_STM32L5.hex SecADD-CW308_NEORV32.hex SecADD-CW312_SAM4S.hex SecADD-CW305_IBEX.hex SecADD-CW312_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- SecADD-CW308_CC2538.eep SecADD-CW301_AVR.eep SecADD-CW303.eep SecADD-CW304.eep SecADD-CW308_MEGARF.eep SecADD-CW308_SAM4L.eep SecADD-CW308_STM32F0.eep SecADD-CW308_STM32F1.eep SecADD-CW308_STM32F2.eep SecADD-CW308_STM32F3.eep SecADD-CW308_STM32F4.eep SecADD-CW308_K24F.eep SecADD-CW308_NRF52.eep SecADD-CW308_AURIX.eep SecADD-CW308_SAML11.eep SecADD-CW308_EFM32TG11B.eep SecADD-CWLITEARM.eep SecADD-CWLITEXMEGA.eep SecADD-CWNANO.eep SecADD-CWHUSKY.eep SecADD-CW308_K82F.eep SecADD-CW308_PSOC62.eep SecADD-CW308_IMXRT1062.eep SecADD-CW308_FE310.eep SecADD-CW308_EFR32MG21A.eep SecADD-CW308_EFM32GG11.eep SecADD-CW308_STM32L5.eep SecADD-CW308_NEORV32.eep SecADD-CW312_SAM4S.eep SecADD-CW305_IBEX.eep SecADD-CW312_IBEX.eep
# rm -f -- SecADD-CW308_CC2538.bin SecADD-CW301_AVR.bin SecADD-CW303.bin SecADD-CW304.bin SecADD-CW308_MEGARF.bin SecADD-CW308_SAM4L.bin SecADD-CW308_STM32F0.bin SecADD-CW308_STM32F1.bin SecADD-CW308_STM32F2.bin SecADD-CW308_STM32F3.bin SecADD-CW308_STM32F4.bin SecADD-CW308_K24F.bin SecADD-CW308_NRF52.bin SecADD-CW308_AURIX.bin SecADD-CW308_SAML11.bin SecADD-CW308_EFM32TG11B.bin SecADD-CWLITEARM.bin SecADD-CWLITEXMEGA.bin SecADD-CWNANO.bin SecADD-CWHUSKY.bin SecADD-CW308_K82F.bin SecADD-CW308_PSOC62.bin SecADD-CW308_IMXRT1062.bin SecADD-CW308_FE310.bin SecADD-CW308_EFR32MG21A.bin SecADD-CW308_EFM32GG11.bin SecADD-CW308_STM32L5.bin SecADD-CW308_NEORV32.bin SecADD-CW312_SAM4S.bin SecADD-CW305_IBEX.bin SecADD-CW312_IBEX.bin
# rm -f -- SecADD-CW308_CC2538.cof SecADD-CW301_AVR.cof SecADD-CW303.cof SecADD-CW304.cof SecADD-CW308_MEGARF.cof SecADD-CW308_SAM4L.cof SecADD-CW308_STM32F0.cof SecADD-CW308_STM32F1.cof SecADD-CW308_STM32F2.cof SecADD-CW308_STM32F3.cof SecADD-CW308_STM32F4.cof SecADD-CW308_K24F.cof SecADD-CW308_NRF52.cof SecADD-CW308_AURIX.cof SecADD-CW308_SAML11.cof SecADD-CW308_EFM32TG11B.cof SecADD-CWLITEARM.cof SecADD-CWLITEXMEGA.cof SecADD-CWNANO.cof SecADD-CWHUSKY.cof SecADD-CW308_K82F.cof SecADD-CW308_PSOC62.cof SecADD-CW308_IMXRT1062.cof SecADD-CW308_FE310.cof SecADD-CW308_EFR32MG21A.cof SecADD-CW308_EFM32GG11.cof SecADD-CW308_STM32L5.cof SecADD-CW308_NEORV32.cof SecADD-CW312_SAM4S.cof SecADD-CW305_IBEX.cof SecADD-CW312_IBEX.cof
# rm -f -- SecADD-CW308_CC2538.elf SecADD-CW301_AVR.elf SecADD-CW303.elf SecADD-CW304.elf SecADD-CW308_MEGARF.elf SecADD-CW308_SAM4L.elf SecADD-CW308_STM32F0.elf SecADD-CW308_STM32F1.elf SecADD-CW308_STM32F2.elf SecADD-CW308_STM32F3.elf SecADD-CW308_STM32F4.elf SecADD-CW308_K24F.elf SecADD-CW308_NRF52.elf SecADD-CW308_AURIX.elf SecADD-CW308_SAML11.elf SecADD-CW308_EFM32TG11B.elf SecADD-CWLITEARM.elf SecADD-CWLITEXMEGA.elf SecADD-CWNANO.elf SecADD-CWHUSKY.elf SecADD-CW308_K82F.elf SecADD-CW308_PSOC62.elf SecADD-CW308_IMXRT1062.elf SecADD-CW308_FE310.elf SecADD-CW308_EFR32MG21A.elf SecADD-CW308_EFM32GG11.elf SecADD-CW308_STM32L5.elf SecADD-CW308_NEORV32.elf SecADD-CW312_SAM4S.elf SecADD-CW305_IBEX.elf SecADD-CW312_IBEX.elf
# rm -f -- SecADD-CW308_CC2538.map SecADD-CW301_AVR.map SecADD-CW303.map SecADD-CW304.map SecADD-CW308_MEGARF.map SecADD-CW308_SAM4L.map SecADD-CW308_STM32F0.map SecADD-CW308_STM32F1.map SecADD-CW308_STM32F2.map SecADD-CW308_STM32F3.map SecADD-CW308_STM32F4.map SecADD-CW308_K24F.map SecADD-CW308_NRF52.map SecADD-CW308_AURIX.map SecADD-CW308_SAML11.map SecADD-CW308_EFM32TG11B.map SecADD-CWLITEARM.map SecADD-CWLITEXMEGA.map SecADD-CWNANO.map SecADD-CWHUSKY.map SecADD-CW308_K82F.map SecADD-CW308_PSOC62.map SecADD-CW308_IMXRT1062.map SecADD-CW308_FE310.map SecADD-CW308_EFR32MG21A.map SecADD-CW308_EFM32GG11.map SecADD-CW308_STM32L5.map SecADD-CW308_NEORV32.map SecADD-CW312_SAM4S.map SecADD-CW305_IBEX.map SecADD-CW312_IBEX.map
# rm -f -- SecADD-CW308_CC2538.sym SecADD-CW301_AVR.sym SecADD-CW303.sym SecADD-CW304.sym SecADD-CW308_MEGARF.sym SecADD-CW308_SAM4L.sym SecADD-CW308_STM32F0.sym SecADD-CW308_STM32F1.sym SecADD-CW308_STM32F2.sym SecADD-CW308_STM32F3.sym SecADD-CW308_STM32F4.sym SecADD-CW308_K24F.sym SecADD-CW308_NRF52.sym SecADD-CW308_AURIX.sym SecADD-CW308_SAML11.sym SecADD-CW308_EFM32TG11B.sym SecADD-CWLITEARM.sym SecADD-CWLITEXMEGA.sym SecADD-CWNANO.sym SecADD-CWHUSKY.sym SecADD-CW308_K82F.sym SecADD-CW308_PSOC62.sym SecADD-CW308_IMXRT1062.sym SecADD-CW308_FE310.sym SecADD-CW308_EFR32MG21A.sym SecADD-CW308_EFM32GG11.sym SecADD-CW308_STM32L5.sym SecADD-CW308_NEORV32.sym SecADD-CW312_SAM4S.sym SecADD-CW305_IBEX.sym SecADD-CW312_IBEX.sym
# rm -f -- SecADD-CW308_CC2538.lss SecADD-CW301_AVR.lss SecADD-CW303.lss SecADD-CW304.lss SecADD-CW308_MEGARF.lss SecADD-CW308_SAM4L.lss SecADD-CW308_STM32F0.lss SecADD-CW308_STM32F1.lss SecADD-CW308_STM32F2.lss SecADD-CW308_STM32F3.lss SecADD-CW308_STM32F4.lss SecADD-CW308_K24F.lss SecADD-CW308_NRF52.lss SecADD-CW308_AURIX.lss SecADD-CW308_SAML11.lss SecADD-CW308_EFM32TG11B.lss SecADD-CWLITEARM.lss SecADD-CWLITEXMEGA.lss SecADD-CWNANO.lss SecADD-CWHUSKY.lss SecADD-CW308_K82F.lss SecADD-CW308_PSOC62.lss SecADD-CW308_IMXRT1062.lss SecADD-CW308_FE310.lss SecADD-CW308_EFR32MG21A.lss SecADD-CW308_EFM32GG11.lss SecADD-CW308_STM32L5.lss SecADD-CW308_NEORV32.lss SecADD-CW312_SAM4S.lss SecADD-CW305_IBEX.lss SecADD-CW312_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# Compiling:
# .
# Compiling:
# .
# .
# -en     project.c ...
# Compiling:
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# Compiling:
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# .
# .
# Assembling: SecBA_m4.S
# .
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecBA_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecBA_m4.S -o objdir-CWLITEARM/SecBA_m4.o
# .
# Assembling: SecAB_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAB_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAB_m4.S -o objdir-CWLITEARM/SecAB_m4.o
# Assembling: SecADD_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecADD_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecADD_m4.S -o objdir-CWLITEARM/SecADD_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecADD-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       12348 B       256 KB      4.71%
# -e Done!
# .
# .
# .
# Creating load file for Flash: SecADD-CWLITEARM.hex
# Creating load file for Flash: SecADD-CWLITEARM.bin
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecADD-CWLITEARM.elf SecADD-CWLITEARM.hex
# .
# Creating load file for EEPROM: SecADD-CWLITEARM.eep
# .
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecADD-CWLITEARM.elf SecADD-CWLITEARM.bin
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecADD-CWLITEARM.elf SecADD-CWLITEARM.eep || exit 0
# Creating Extended Listing: SecADD-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z SecADD-CWLITEARM.elf > SecADD-CWLITEARM.lss
# Creating Symbol Table: SecADD-CWLITEARM.sym
# arm-none-eabi-nm -n SecADD-CWLITEARM.elf > SecADD-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   12324	     24	   1688	  14036	   36d4	SecADD-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecADD-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 12347 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 12347 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = FIXED ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])

        mask = randbits(32)
        y0 = FIXED ^ mask
        y1 = mask

        y0_0 = y0 % (2**8)
        y0_1 = (y0 % (2**16)) >> 8
        y0_2 = (y0 % (2**24)) >> 16
        y0_3 = y0 >> 24

        y1_0 = y1 % (2**8)
        y1_1 = (y1 % (2**16)) >> 8
        y1_2 = (y1 % (2**24)) >> 16
        y1_3 = y1 >> 24
        
        fixed_text.extend([y0_0, y0_1, y0_2, y0_3, y1_0, y1_1, y1_2, y1_3])

        randomness = bytearray([randbits(8) for _ in range(12)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = (x0^x1) + (y0^y1)

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            rnd_y0 = (text[11] << 24) |(text[10] << 16) | (text[9] << 8) | text[8]
            rnd_y1 = (text[15] << 24) |(text[14] << 16) | (text[13] << 8) | text[12]
            
            val = ((rnd_x0 ^ rnd_x1) + (rnd_y0 ^ rnd_y1)) %2**32 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())

        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 2484 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
