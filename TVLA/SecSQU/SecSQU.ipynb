# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# /home/mert/chipwhisperer/software/chipwhisperer/capture/trace/TraceWhisperer.py:31: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources # type: ignore
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 8100045                   to 18651428
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen

# %%
samples = 600
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecSQU-CW308_CC2538.hex SecSQU-CW301_AVR.hex SecSQU-CW303.hex SecSQU-CW304.hex SecSQU-CW308_MEGARF.hex SecSQU-CW308_SAM4L.hex SecSQU-CW308_STM32F0.hex SecSQU-CW308_STM32F1.hex SecSQU-CW308_STM32F2.hex SecSQU-CW308_STM32F3.hex SecSQU-CW308_STM32F4.hex SecSQU-CW308_K24F.hex SecSQU-CW308_NRF52.hex SecSQU-CW308_AURIX.hex SecSQU-CW308_SAML11.hex SecSQU-CW308_EFM32TG11B.hex SecSQU-CWLITEARM.hex SecSQU-CWLITEXMEGA.hex SecSQU-CWNANO.hex SecSQU-CWHUSKY.hex SecSQU-CW308_K82F.hex SecSQU-CW308_PSOC62.hex SecSQU-CW308_IMXRT1062.hex SecSQU-CW308_FE310.hex SecSQU-CW308_EFR32MG21A.hex SecSQU-CW308_EFM32GG11.hex SecSQU-CW308_STM32L5.hex SecSQU-CW308_NEORV32.hex SecSQU-CW312_SAM4S.hex SecSQU-CW305_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- SecSQU-CW308_CC2538.eep SecSQU-CW301_AVR.eep SecSQU-CW303.eep SecSQU-CW304.eep SecSQU-CW308_MEGARF.eep SecSQU-CW308_SAM4L.eep SecSQU-CW308_STM32F0.eep SecSQU-CW308_STM32F1.eep SecSQU-CW308_STM32F2.eep SecSQU-CW308_STM32F3.eep SecSQU-CW308_STM32F4.eep SecSQU-CW308_K24F.eep SecSQU-CW308_NRF52.eep SecSQU-CW308_AURIX.eep SecSQU
# rm -f -- SecSQU-CW308_CC2538.lss SecSQU-CW301_AVR.lss SecSQU-CW303.lss SecSQU-CW304.lss SecSQU-CW308_MEGARF.lss SecSQU-CW308_SAM4L.lss SecSQU-CW308_STM32F0.lss SecSQU-CW308_STM32F1.lss SecSQU-CW308_STM32F2.lss SecSQU-CW308_STM32F3.lss SecSQU-CW308_STM32F4.lss SecSQU-CW308_K24F.lss SecSQU-CW308_NRF52.lss SecSQU-CW308_AURIX.lss SecSQU-CW308_SAML11.lss SecSQU-CW308_EFM32TG11B.lss SecSQU-CWLITEARM.lss SecSQU-CWLITEXMEGA.lss SecSQU-CWNANO.lss SecSQU-CWHUSKY.lss SecSQU-CW308_K82F.lss SecSQU-CW308_PSOC62.lss SecSQU-CW308_IMXRT1062.lss SecSQU-CW308_FE310.lss SecSQU-CW308_EFR32MG21A.lss SecSQU-CW308_EFM32GG11.lss SecSQU-CW308_STM32L5.lss SecSQU-CW308_NEORV32.lss SecSQU-CW312_SAM4S.lss SecSQU-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# Compiling:
# .
# Compiling:
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# .
# .
# Compiling:
# Compiling:
# .
# .
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: SecSQU_m4.S
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecSQU_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecSQU_m4.S -o objdir-CWLITEARM/SecSQU_m4.o
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecSQU-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       10872 B       256 KB      4.15%
# -e Done!
# .
# .
# .
# .
# Creating load file for Flash: SecSQU-CWLITEARM.hex
# Creating load file for Flash: SecSQU-CWLITEARM.bin
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecSQU-CWLITEARM.elf SecSQU-CWLITEARM.hex
# Creating load file for EEPROM: SecSQU-CWLITEARM.eep
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecSQU-CWLITEARM.elf SecSQU-CWLITEARM.bin
# Creating Extended Listing: SecSQU-CWLITEARM.lss
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecSQU-CWLITEARM.elf SecSQU-CWLITEARM.eep || exit 0
# arm-none-eabi-objdump -h -S -z SecSQU-CWLITEARM.elf > SecSQU-CWLITEARM.lss
# .
# Creating Symbol Table: SecSQU-CWLITEARM.sym
# arm-none-eabi-nm -n SecSQU-CWLITEARM.elf > SecSQU-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   10848	     24	   1688	  12560	   3110	SecSQU-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecSQU-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 10871 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 10871 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = (FIXED + mask) % 2**32
        x1 = (-mask) % 2**32

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
        randomness = bytearray([randbits(8) for _ in range(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = ((x0 + x1) * (x0 + x1)) % 2**32 

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            
            val = ((rnd_x0 + rnd_x1) * (rnd_x0 + rnd_x1)) % 2**32 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())

        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3     VERBOSE = False
#       4     nb_traces = 200000
# ----> 5     traces_1, traces_2, x = get_traces(nb_traces)
#       6 else:
#       7     VERBOSE = True
#
# Cell In[6], line 53, in get_traces(N)
#      50 val = ((rnd_x0 + rnd_x1) * (rnd_x0 + rnd_x1)) % 2**32
#      52 target.simpleserial_write('p', text)
# ---> 53 ret = scope.capture()
#      54 if ret:
#      55     print("Target timed out!")
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:868, in OpenADC.capture(self, poll_done)
#     866     a = self.sc.capture(None)
#     867 else:
# --> 868     a = self.sc.capture(self.adc.offset, self.clock.adc_freq, self.adc.samples, self.adc.segments, self.adc.segment_cycles, poll_done)
#     870 # _capture_read() must be given the total number of samples to read; in the case of Husky, self.adc.samples
#     871 # is the number of samples *per segment*, so adjust accordingly:
#     872 if self._is_husky:
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:726, in OpenADCInterface.capture(self, offset, adc_freq, samples, segments, segment_cycles, poll_done)
#     724 # Wait for a trigger
#     725 while ((status & STATUS_ARM_MASK) == STATUS_ARM_MASK) | ((status & STATUS_FIFO_MASK) == 0):
# --> 726     status = self.getStatus()
#     728     diff = datetime.datetime.now() - starttime
#     730     # If we've timed out, don't wait any longer for a trigger
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:467, in OpenADCInterface.getStatus(self)
#     466 def getStatus(self):
# --> 467     result = self.sendMessage(CODE_READ, "STATUS_ADDR")
#     469     if len(result) == 1:
#     470         return result[0]
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:290, in OpenADCInterface.sendMessage(self, mode, address, payload, Validate, maxResp, readMask)
#     288 address = self._address_str2int(address)
#     289 if mode != CODE_WRITE:
# --> 290     return self.msg_read(address, maxResp)
#     291 self.msg_write(address, payload)
#     292 if Validate:
#
# File ~/chipwhisperer/software/chipwhisperer/capture/scopes/_OpenADCInterface.py:214, in OpenADCInterface.msg_read(self, address, max_resp)
#     211         scope_logger.warning("The error trace below will show you what led to this:")
#     212         raise ValueError
# --> 214     data = self.serial.cmdReadMem(address, max_resp)
#     215 else:
#     216     self._send_msg_hdr(CODE_READ, address, 0)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:889, in NAEUSB.cmdReadMem(self, addr, dlen)
#     883 def cmdReadMem(self, addr : int, dlen : int) -> bytearray:
#     884     """
#     885     Send command to read over external memory interface from FPGA. Automatically
#     886     decides to use control-transfer or bulk-endpoint transfer based on data length.
#     887     """
# --> 889     return self.usbserializer.cmdReadMem(addr, dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:635, in NAEUSB_Backend.cmdReadMem(self, addr, dlen)
#     633 dlen = int(dlen)
#     634 if dlen < NAEUSB_CTRL_IO_THRESHOLD:
# --> 635     data = self._cmd_readmem_ctrl(addr, dlen)
#     636 else:
#     637     data = self._cmd_readmem_bulk(addr, dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:617, in NAEUSB_Backend._cmd_readmem_ctrl(self, addr, dlen)
#     611 """Reads data from the external memory interface over the control-transfer endpoint.
#     612
#     613 Returns:
#     614     The received data.
#     615 """
#     616 self._cmd_ctrl_send_header(addr, dlen, self.CMD_READMEM_CTRL);
# --> 617 return self.readCtrl(self.CMD_READMEM_CTRL, dlen=dlen)
#
# File ~/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:561, in NAEUSB_Backend.readCtrl(self, cmd, value, dlen)
#     559 if dlen > NAEUSB_CTRL_IO_MAX:
#     560     naeusb_logger.error("The naeusb fw ctrl buffer is 128 bytes, but len(data) > 128. If you get a pipe error, this is why.")
# --> 561 response = self.handle.controlRead(0xC1, cmd, value, 0, dlen, timeout=self._timeout)
#     562 naeusb_logger.debug("READ_CTRL: bmRequestType: {:02X}, \
#     563             bRequest: {:02X}, wValue: {:04X}, wIndex: {:04X}, data_len: {:04X}, response: {}".format(0xC1, cmd, \
#     564                 value, 0, dlen, response))
#     565 return response
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1426, in USBDeviceHandle.controlRead(self, request_type, request, value, index, length, timeout)
#    1424 # pylint: enable=undefined-variable
#    1425 data, data_buffer = create_binary_buffer(length)
# -> 1426 transferred = self._controlTransfer(
#    1427     request_type, request, value, index, data, length, timeout,
#    1428 )
#    1429 return data_buffer[:transferred]
#
# File ~/.cwvenv/lib/python3.12/site-packages/usb1/__init__.py:1379, in USBDeviceHandle._controlTransfer(self, request_type, request, value, index, data, length, timeout)
#    1377 def _controlTransfer(
#    1378         self, request_type, request, value, index, data, length, timeout):
# -> 1379     result = libusb1.libusb_control_transfer(
#    1380         self.__handle, request_type, request, value, index, data, length,
#    1381         timeout,
#    1382     )
#    1383     mayRaiseUSBError(result)
#    1384     return result
#
# KeyboardInterrupt:

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
