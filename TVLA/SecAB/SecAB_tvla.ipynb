# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 3000                      to 5000

# %%
GADGET = "AB"  # possible values are ["AB", "BA", "AND", "ADD", "ZERO"]
ARCH = 'asm' # possible values are ["c", "asm", "naive_asm"]

if ARCH == 'asm':
    samples = {"AB": 1900, "BA": 400, "AND": 900, "ADD": 1100, "ZERO": 1200}
elif ARCH == 'naive_asm':
    samples = {"AB": 600, "BA": 300, "AND": 300, "ADD": 700, "ZERO": 600}
elif ARCH == 'c':
    samples = {"AB": 500, "BA": 200, "AND": 300, "ADD": 500, "ZERO": 500}

randomness = {"AB":2, "BA": 2, "AND": 2, "ADD": 6, "ZERO": 18}
RAND = randomness[GADGET]
scope.adc.samples = samples[GADGET]

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER" "$GADGET" "$ARCH" "$RAND"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 GADGET=$4 ARCH=$5 RAND=$6 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecAB-CW308_CC2538.hex SecAB-CW301_AVR.hex SecAB-CW303.hex SecAB-CW304.hex SecAB-CW308_MEGARF.hex SecAB-CW308_SAM4L.hex SecAB-CW308_STM32F0.hex SecAB-CW308_STM32F1.hex SecAB-CW308_STM32F2.hex SecAB-CW308_STM32F3.hex SecAB-CW308_STM32F4.hex SecAB-CW308_K24F.hex SecAB-CW308_NRF52.hex SecAB-CW308_AURIX.hex SecAB-CW308_SAML11.hex SecAB-CW308_EFM32TG11B.hex SecAB-CWLITEARM.hex SecAB-CWLITEXMEGA.hex SecAB-CWNANO.hex SecAB-CWHUSKY.hex SecAB-CW308_K82F.hex SecAB-CW308_PSOC62.hex SecAB-CW308_IMXRT1062.hex SecAB-CW308_FE310.hex SecAB-CW308_EFR32MG21A.hex SecAB-CW308_EFM32GG11.hex SecAB-CW308_STM32L5.hex SecAB-CW308_NEORV32.hex SecAB-CW312_SAM4S.hex SecAB-CW305_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- SecAB-CW308_CC2538.eep SecAB-CW301_AVR.eep SecAB-CW303.eep SecAB-CW304.eep SecAB-CW308_MEGARF.eep SecAB-CW308_SAM4L.eep SecAB-CW308_STM32F0.eep SecAB-CW308_STM32F1.eep SecAB-CW308_STM32F2.eep SecAB-CW308_STM32F3.eep SecAB-CW308_STM32F4.eep SecAB-CW308_K24F.eep SecAB-CW308_NRF52.eep SecAB-CW308_AURIX.eep SecAB-CW308_SAML11.eep SecAB-CW308_EFM32TG11B.eep SecAB-CWLITEARM.eep SecAB-CWLITEXMEGA.eep SecAB-CWNANO.eep SecAB-CWHUSKY.eep SecAB-CW308_K82F.eep SecAB-CW308_PSOC62.eep SecAB-CW308_IMXRT1062.eep SecAB-CW308_FE310.eep SecAB-CW308_EFR32MG21A.eep SecAB-CW308_EFM32GG11.eep SecAB-CW308_STM32L5.eep SecAB-CW308_NEORV32.eep SecAB-CW312_SAM4S.eep SecAB-CW305_IBEX.eep
# rm -f -- SecAB-CW308_CC2538.bin SecAB-CW301_AVR.bin SecAB-CW303.bin SecAB-CW304.bin SecAB-CW308_MEGARF.bin SecAB-CW308_SAM4L.bin SecAB-CW308_STM32F0.bin SecAB-CW308_STM32F1.bin SecAB-CW308_STM32F2.bin SecAB-CW308_STM32F3.bin SecAB-CW308_STM32F4.bin SecAB-CW308_K24F.bin SecAB-CW308_NRF52.bin SecAB-CW308_AURIX.bin SecAB-CW308_SAML11.bin SecAB-CW308_EFM32TG11B.bin SecAB-CWLITEARM.bin SecAB-CWLITEXMEGA.bin SecAB-CWNANO.bin SecAB-CWHUSKY.bin SecAB-CW308_K82F.bin SecAB-CW308_PSOC62.bin SecAB-CW308_IMXRT1062.bin SecAB-CW308_FE310.bin SecAB-CW308_EFR32MG21A.bin SecAB-CW308_EFM32GG11.bin SecAB-CW308_STM32L5.bin SecAB-CW308_NEORV32.bin SecAB-CW312_SAM4S.bin SecAB-CW305_IBEX.bin
# rm -f -- SecAB-CW308_CC2538.cof SecAB-CW301_AVR.cof SecAB-CW303.cof SecAB-CW304.cof SecAB-CW308_MEGARF.cof SecAB-CW308_SAM4L.cof SecAB-CW308_STM32F0.cof SecAB-CW308_STM32F1.cof SecAB-CW308_STM32F2.cof SecAB-CW308_STM32F3.cof SecAB-CW308_STM32F4.cof SecAB-CW308_K24F.cof SecAB-CW308_NRF52.cof SecAB-CW308_AURIX.cof SecAB-CW308_SAML11.cof SecAB-CW308_EFM32TG11B.cof SecAB-CWLITEARM.cof SecAB-CWLITEXMEGA.cof SecAB-CWNANO.cof SecAB-CWHUSKY.cof SecAB-CW308_K82F.cof SecAB-CW308_PSOC62.cof SecAB-CW308_IMXRT1062.cof SecAB-CW308_FE310.cof SecAB-CW308_EFR32MG21A.cof SecAB-CW308_EFM32GG11.cof SecAB-CW308_STM32L5.cof SecAB-CW308_NEORV32.cof SecAB-CW312_SAM4S.cof SecAB-CW305_IBEX.cof
# rm -f -- SecAB-CW308_CC2538.elf SecAB-CW301_AVR.elf SecAB-CW303.elf SecAB-CW304.elf SecAB-CW308_MEGARF.elf SecAB-CW308_SAM4L.elf SecAB-CW308_STM32F0.elf SecAB-CW308_STM32F1.elf SecAB-CW308_STM32F2.elf SecAB-CW308_STM32F3.elf SecAB-CW308_STM32F4.elf SecAB-CW308_K24F.elf SecAB-CW308_NRF52.elf SecAB-CW308_AURIX.elf SecAB-CW308_SAML11.elf SecAB-CW308_EFM32TG11B.elf SecAB-CWLITEARM.elf SecAB-CWLITEXMEGA.elf SecAB-CWNANO.elf SecAB-CWHUSKY.elf SecAB-CW308_K82F.elf SecAB-CW308_PSOC62.elf SecAB-CW308_IMXRT1062.elf SecAB-CW308_FE310.elf SecAB-CW308_EFR32MG21A.elf SecAB-CW308_EFM32GG11.elf SecAB-CW308_STM32L5.elf SecAB-CW308_NEORV32.elf SecAB-CW312_SAM4S.elf SecAB-CW305_IBEX.elf
# rm -f -- SecAB-CW308_CC2538.map SecAB-CW301_AVR.map SecAB-CW303.map SecAB-CW304.map SecAB-CW308_MEGARF.map SecAB-CW308_SAM4L.map SecAB-CW308_STM32F0.map SecAB-CW308_STM32F1.map SecAB-CW308_STM32F2.map SecAB-CW308_STM32F3.map SecAB-CW308_STM32F4.map SecAB-CW308_K24F.map SecAB-CW308_NRF52.map SecAB-CW308_AURIX.map SecAB-CW308_SAML11.map SecAB-CW308_EFM32TG11B.map SecAB-CWLITEARM.map SecAB-CWLITEXMEGA.map SecAB-CWNANO.map SecAB-CWHUSKY.map SecAB-CW308_K82F.map SecAB-CW308_PSOC62.map SecAB-CW308_IMXRT1062.map SecAB-CW308_FE310.map SecAB-CW308_EFR32MG21A.map SecAB-CW308_EFM32GG11.map SecAB-CW308_STM32L5.map SecAB-CW308_NEORV32.map SecAB-CW312_SAM4S.map SecAB-CW305_IBEX.map
# rm -f -- SecAB-CW308_CC2538.sym SecAB-CW301_AVR.sym SecAB-CW303.sym SecAB-CW304.sym SecAB-CW308_MEGARF.sym SecAB-CW308_SAM4L.sym SecAB-CW308_STM32F0.sym SecAB-CW308_STM32F1.sym SecAB-CW308_STM32F2.sym SecAB-CW308_STM32F3.sym SecAB-CW308_STM32F4.sym SecAB-CW308_K24F.sym SecAB-CW308_NRF52.sym SecAB-CW308_AURIX.sym SecAB-CW308_SAML11.sym SecAB-CW308_EFM32TG11B.sym SecAB-CWLITEARM.sym SecAB-CWLITEXMEGA.sym SecAB-CWNANO.sym SecAB-CWHUSKY.sym SecAB-CW308_K82F.sym SecAB-CW308_PSOC62.sym SecAB-CW308_IMXRT1062.sym SecAB-CW308_FE310.sym SecAB-CW308_EFR32MG21A.sym SecAB-CW308_EFM32GG11.sym SecAB-CW308_STM32L5.sym SecAB-CW308_NEORV32.sym SecAB-CW312_SAM4S.sym SecAB-CW305_IBEX.sym
# rm -f -- SecAB-CW308_CC2538.lss SecAB-CW301_AVR.lss SecAB-CW303.lss SecAB-CW304.lss SecAB-CW308_MEGARF.lss SecAB-CW308_SAM4L.lss SecAB-CW308_STM32F0.lss SecAB-CW308_STM32F1.lss SecAB-CW308_STM32F2.lss SecAB-CW308_STM32F3.lss SecAB-CW308_STM32F4.lss SecAB-CW308_K24F.lss SecAB-CW308_NRF52.lss SecAB-CW308_AURIX.lss SecAB-CW308_SAML11.lss SecAB-CW308_EFM32TG11B.lss SecAB-CWLITEARM.lss SecAB-CWLITEXMEGA.lss SecAB-CWNANO.lss SecAB-CWHUSKY.lss SecAB-CW308_K82F.lss SecAB-CW308_PSOC62.lss SecAB-CW308_IMXRT1062.lss SecAB-CW308_FE310.lss SecAB-CW308_EFR32MG21A.lss SecAB-CW308_EFM32GG11.lss SecAB-CW308_STM32L5.lss SecAB-CW308_NEORV32.lss SecAB-CW312_SAM4S.lss SecAB-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# Compiling:
# .
# Compiling:
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# .
# .
# .
# Compiling:
# .
# Compiling:
# Assembling: SecAB_m4.S
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAB_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAB_m4.S -o objdir-CWLITEARM/SecAB_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecAB-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       11984 B       256 KB      4.57%
# -e Done!
# .
# .
# Creating load file for Flash: SecAB-CWLITEARM.hex
# .
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecAB-CWLITEARM.elf SecAB-CWLITEARM.hex
# Creating load file for Flash: SecAB-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecAB-CWLITEARM.elf SecAB-CWLITEARM.bin
# Creating load file for EEPROM: SecAB-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecAB-CWLITEARM.elf SecAB-CWLITEARM.eep || exit 0
# .
# .
# Creating Extended Listing: SecAB-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z SecAB-CWLITEARM.elf > SecAB-CWLITEARM.lss
# Creating Symbol Table: SecAB-CWLITEARM.sym
# arm-none-eabi-nm -n SecAB-CWLITEARM.elf > SecAB-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   11960	     24	   1688	  13672	   3568	SecAB-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecAB-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 11983 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 11983 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = (FIXED + mask) % 2**32
        x1 = (-mask) % 2**32

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
        
        randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = FIXED

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            #print(t)
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            
            val = (rnd_x0 + rnd_x1) % 2**32
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())
 
        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 50000
    traces_1, traces_2, x = get_traces(nb_traces)
    #traces_1_arr = np.array(traces_1)
    #traces_2_arr = np.array(traces_2)
    #np.save('traces_1.npy', traces_1_arr)
    #np.save('traces_2.npy', traces_2_arr)
elif ch == 1:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
else:    
    traces_1 = np.load('traces_1.npy')
    traces_2 = np.load('traces_2.npy')
# Out:
# Capturing traces:   0%|          | 0/50000 [00:00<?, ?it/s]
# Trigger up for 1824 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples[GADGET])
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples

t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.5)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color = 'r')
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
plt.close()
for t in traces_1[:1]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
np.save("t-test-{}-{}-{}.npy".format(str(nb_traces), GADGET, ARCH), t_val)

# %%
target.dis()
scope.dis()
# Out:
# True
